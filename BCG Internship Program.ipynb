# %% [markdown]
# <font color = "purple">
# <h2>
# <u>BCG Data Science Program
# </u>
# </h2>
# </font>

# %% [markdown]
# <h2>
# TASK 1
# <font color="black">
# <h4>
# 1.Data Cleaning and Replacing NaN values.
#
# 2.Exploratory Data Analysis
# </h4>
# </font>
# </h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px

# %%
data1=pd.read_csv("C:\\Users\\hp\\Downloads\\ml_case_training_data.csv")
data2=pd.read_csv("C:\\Users\\hp\\Downloads\\ml_case_training_hist_data.csv")
data3=pd.read_csv("C:\\Users\\hp\\Downloads\\ml_case_training_output.csv")

# %% [markdown]
# <font color = "purple">
# <h3>
# First Data Set
# </h3>
# </font>

# %%
data1.head(5)
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN
# 4  bba03439a292a1e166f80264c16191cb                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# 1                NaN  foosdfpfkusacimwkcsosbicdxkicaua         0
# 2                NaN                               NaN      4660
# 3                NaN  foosdfpfkusacimwkcsosbicdxkicaua       544
# 4                NaN  lmkebamcaaclubfxadlmueccxoimlema      1584
#
#    cons_gas_12m  cons_last_month  date_activ    date_end date_first_activ  \
# 0             0            10025  2012-11-07  2016-11-06              NaN
# ...

# %%
data1.columns
# Out:
# Index(['id', 'activity_new', 'campaign_disc_ele', 'channel_sales', 'cons_12m',
#        'cons_gas_12m', 'cons_last_month', 'date_activ', 'date_end',
#        'date_first_activ', 'date_modif_prod', 'date_renewal',
#        'forecast_base_bill_ele', 'forecast_base_bill_year',
#        'forecast_bill_12m', 'forecast_cons', 'forecast_cons_12m',
#        'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_p1',
#        'forecast_price_energy_p2', 'forecast_price_pow_p1', 'has_gas',
#        'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'origin_up', 'pow_max'],
#       dtype='object')

# %%
data1.dtypes
# Out:
# id                           object
# activity_new                 object
# campaign_disc_ele           float64
# channel_sales                object
# cons_12m                      int64
# cons_gas_12m                  int64
# cons_last_month               int64
# date_activ                   object
# date_end                     object
# date_first_activ             object
# date_modif_prod              object
# date_renewal                 object
# forecast_base_bill_ele      float64
# forecast_base_bill_year     float64
# forecast_bill_12m           float64
# forecast_cons               float64
# forecast_cons_12m           float64
# forecast_cons_year            int64
# forecast_discount_energy    float64
# forecast_meter_rent_12m     float64
# forecast_price_energy_p1    float64
# forecast_price_energy_p2    float64
# forecast_price_pow_p1       float64
# has_gas                      object
# imp_cons                    float64
# margin_gross_pow_ele        float64
# ...

# %%
data1.shape
# Out:
# (16096, 32)

# %%
data1 = data1.replace([np.inf, -np.inf], np.nan)

# %%
sns.countplot(x="activity_new",data=data1,palette="hls")
plt.show()

# %%
sns.pairplot(data1)

# %%
pd.crosstab(data1.activity_new,data1.channel_sales).plot(kind='bar')
plt.title("New Actitivty V/S channel_sales")
plt.xlabel("New Activities")
plt.ylabel("New Channel Sales")
# Out:
# Text(0, 0.5, 'New Channel Sales')

# %%
x=data1.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(x,annot=True)
plt.show()

# %%
cols=data1.columns[:32]
colors=["#000099","#ffff00"]
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colors))

# %%
values = {"date_first_activ": 0, "campaign_disc_ele": 0, "activity_new": 0, "channel_sales": 0}
data1.fillna(value=values)
# Out:
#                                      id                      activity_new  \
# 0      48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1      24011ae4ebbe3035111d65fa7c15bc57                                 0
# 2      d29c2c54acc38ff3c0614d0a653813dd                                 0
# 3      764c75f661154dac3a6c254cd082ea7d                                 0
# 4      bba03439a292a1e166f80264c16191cb                                 0
# ...                                 ...                               ...
# 16091  18463073fb097fc0ac5d3e040f356987                                 0
# 16092  d0a6f71671571ed83b2645d23af6de00                                 0
# 16093  10e6828ddd62cbcf687cb74928c4c2d2                                 0
# 16094  1cf20fd6206d7678d5bcafd28c53b4db                                 0
# 16095  563dde550fd624d7352f3de77c0cdfcd                                 0
#
#        campaign_disc_ele                     channel_sales  cons_12m  \
# ...

# %%
sns.catplot(x="activity_new",y="cons_last_month",data=data1)

# %% [markdown]
# <font color = "purple">
# <h3>
# Second Data Set
# </h3>
# </font>

# %%
data2.head(5)
# Out:
#                                  id  price_date  price_p1_var  price_p2_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01      0.151367           0.0
# 1  038af19179925da21a25619c5a24b745  2015-02-01      0.151367           0.0
# 2  038af19179925da21a25619c5a24b745  2015-03-01      0.151367           0.0
# 3  038af19179925da21a25619c5a24b745  2015-04-01      0.149626           0.0
# 4  038af19179925da21a25619c5a24b745  2015-05-01      0.149626           0.0
#
#    price_p3_var  price_p1_fix  price_p2_fix  price_p3_fix
# 0           0.0     44.266931           0.0           0.0
# 1           0.0     44.266931           0.0           0.0
# 2           0.0     44.266931           0.0           0.0
# 3           0.0     44.266931           0.0           0.0
# 4           0.0     44.266931           0.0           0.0

# %%
x=data2.corr()
plt.subplots(figsize=(10,5))
sns.heatmap(x,annot=True)
plt.show()

# %%
cols=data2.columns
colors=["#000099","#ffff00"]
sns.heatmap(data2[cols].isnull(),cmap=sns.color_palette(colors))

# %% [markdown]
# <font color = "purple">
# <h3>
# Third Data Set
# </h3>
# </font>

# %%
data3.head(5)
# Out:
#                                  id  churn
# 0  48ada52261e7cf58715202705a0451c9      0
# 1  24011ae4ebbe3035111d65fa7c15bc57      1
# 2  d29c2c54acc38ff3c0614d0a653813dd      0
# 3  764c75f661154dac3a6c254cd082ea7d      0
# 4  bba03439a292a1e166f80264c16191cb      0

# %%
x=data3.corr()
plt.subplots(figsize=(10,5))
sns.heatmap(x,annot=True)
plt.show()

# %%
cols=data3.columns
colors=["#000099","#ffff00"]
sns.heatmap(data3[cols].isnull(),cmap=sns.color_palette(colors))

# %% [markdown]
# <h2>
# TASK 3
# <font color="black">
# <h4>
# Feature Engineering
# </h4>
# </font>
# </h2>

# %%
#Using the third DataSet
from pandas import read_csv
from collections import Counter

# summarize the class distribution
target = data3.values[:,-1]
counter = Counter(target)
for k,v in counter.items():
	per = v / len(target) * 100
	print('Class=%d, Count=%d, Percentage=%.3f%%' % (k, v, per))
# Out:
# Class=0, Count=14501, Percentage=90.091%
# Class=1, Count=1595, Percentage=9.909%

# %%
churn_rate_percent= 1595/16096*100
print(churn_rate_percent,end=" %")
# Out:
# 9.909294234592446 %

# %%
one_hot1=pd.get_dummies(data3.churn)
df=pd.concat([data3,one_hot1],axis=1)

# %%
df
# Out:
#                                      id  churn  0  1
# 0      48ada52261e7cf58715202705a0451c9      0  1  0
# 1      24011ae4ebbe3035111d65fa7c15bc57      1  0  1
# 2      d29c2c54acc38ff3c0614d0a653813dd      0  1  0
# 3      764c75f661154dac3a6c254cd082ea7d      0  1  0
# 4      bba03439a292a1e166f80264c16191cb      0  1  0
# ...                                 ...    ... .. ..
# 16091  18463073fb097fc0ac5d3e040f356987      0  1  0
# 16092  d0a6f71671571ed83b2645d23af6de00      1  0  1
# 16093  10e6828ddd62cbcf687cb74928c4c2d2      1  0  1
# 16094  1cf20fd6206d7678d5bcafd28c53b4db      0  1  0
# 16095  563dde550fd624d7352f3de77c0cdfcd      0  1  0
#
# [16096 rows x 4 columns]

# %% [markdown]
# <h2>
# TASK 4
# <font color="blue">
# <h4>
# Churn Model : Random Forest Classifier
# </h4>
# </font>
# </h2>

# %%
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
y=data3['churn']
cols=['cons_last_month']
X=data1[cols]

# %%
X_train,X_text,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_text)

# %%
from sklearn import metrics

# %%
print("Accuracy:",metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.8724373576309795
